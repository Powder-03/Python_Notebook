# %% [markdown]
# Python is a case sensitive language

# %% [markdown]
# In programming , a keyword is a word that is reserved by a programming language because it has a special meaning.
# These words cannot be used as identifiers (such as variable names, function names, or class names) because they are part of the syntax of the language.

# %%
#python has 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers

# %% [markdown]
# A python identifier is a name used to identify a variable , function, class , module or other object

# %% [markdown]
# Rules for setting identifiers
# 1. can only start with a alphabet or _
# 2. Followed by 0 or more letters, _ and digits
# 3. keywords cannot be used as an identifiers
