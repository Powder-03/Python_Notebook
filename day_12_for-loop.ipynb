# %%
#range function
list(range(0, 10, 2))
# Out:
# [0, 2, 4, 6, 8]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
#Sequence

# %%
#String 
"kolkata"
# Out:
# 'kolkata'

# %%
("kolkata", "delhi")
# Out:
# ('kolkata', 'delhi')

# %%
#for loop itertes over range funciton or sequence
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in (1 , 2, 3, 4, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
