# %%
# tuples are quite similar to lists

# %%
# create

# %%
T1= ()
print(T1)
# Out:
# ()

# %%
t2 = (1,2,3)
print(t2)
# Out:
# (1, 2, 3)

# %%
t3= (1,2,(3,4))
print(t3)
# Out:
# (1, 2, (3, 4))

# %%
t5 = (1) # it is not tuple
t6 = (1,)
print(t5, t6)
# Out:
# 1 (1,)

# %%
t6 = tuple("Goa")
print(t6)
# Out:
# ('G', 'o', 'a')

# %%
t6 = tuple([1,2,3,4])
print(t6)
# Out:
# (1, 2, 3, 4)

# %%
type(t6)
# Out:
# tuple

# %%
# Access

# %%
print(t2[0])
print(t2[-1])
print(t2[:4])
# Out:
# 1
# 3
# (1, 2, 3)

# %%
# Edit
# tuples does not support item assignment 
# tuples are immutable

# %%
# we can also not elements in a defined tuple

# %%
#Deleting


del t2

# %%
# we can do rest of operations same as list 
# but when we sort tuple then it is changed into list

# %%
#Tuples are read only data type

# %%
#It is highly useful when data integrity is top most priority

# %%
# Assume for a condition when we are tnp manager and we want to maintain records of students
