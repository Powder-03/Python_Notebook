# %%
#while loop
#for loop only two loops in python

# %%
number = input("Enter a number for table:")
i = 1
while i<11:
    print(f"{number} x {i} = {int(number)*i}")
    i += 1
# Out:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120
