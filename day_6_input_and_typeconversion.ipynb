# %%
input()
# Out:
# '54'

# %%
input()
# Out:
# '54'

# %%
first_num = input("Enter the first number")
second_num = input("Enter the second number")

# %%
result = int(first_num) + int(second_num)
print("The sum is:", result)
# Out:
# The sum is: 108

# %%
#when we take input from the user using input() function , it is considered as string by default. So we need to convert it into integer using int() function before performing arithmetic operations.

# %%
#implicit type conversion
4+5.5
# Out:
# 9.5

# %%
4.5+5+5j
# Out:
# (9.5+5j)

# %%
#exlicit type conversion
int(4.5)
# Out:
# 4

# %%
str(45)
# Out:
# '45'

# %%
complex(4)
# Out:
# (4+0j)

# %%
list('Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
#type conversion operations are not permanent unless we assign them to a variable.
a = 4.5
print(int(a))
print(a)  # a is still a float
# Out:
# 4
# 4.5
