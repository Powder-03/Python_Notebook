# %%
print("hello world")
# Out:
# hello world

# %%
print(6)
# Out:
# 6

# %%
print(False)
# Out:
# False

# %%
print("India", "Srilanka" , "Nepal")
# Out:
# India Srilanka Nepal

# %%
print('India',5 , True)
# Out:
# India 5 True

# %%
print("India", "germany", sep="---")
# Out:
# India---germany

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print("hello", end=" ")
print("world")
# Out:
# hello world
