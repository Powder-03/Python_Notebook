# %%
# Modules can be considered to be same as a code library.
# A file containing a set of functions you want to include in your application.
#Examples of python modules are math, sys, os, etc.

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random

# %%
random.randint(1,10)  #random number between 1 and 10
# Out:
# 7

# %%
a = [1,2,3,4,5]
random.shuffle(a)
print(a)
# Out:
# [1, 3, 2, 5, 4]

# %%
import time 
print(time.time())
# Out:
# 1768040473.254716

# %%
time.ctime()
# Out:
# 'Sat Jan 10 15:51:21 2026'

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\risha\\Desktop\\Python_Notebook'

# %%
os.listdir()
# Out:
# ['.git',
#  'day_10_indentation.ipynb',
#  'day_11_while-loop.ipynb',
#  'day_12_for-loop.ipynb',
#  'day_13_nested-loops.ipynb',
#  'day_14_break-continue-pass.ipynb',
#  'day_15_built-in-functions.ipynb',
#  'day_16_built-in-modules.ipynb',
#  'day_1_print-function.ipynb',
#  'day_2_datatypes.ipynb',
#  'day_3_comments.ipynb',
#  'day_4_variables.ipynb',
#  'day_5_keywords.ipynb',
#  'day_6_input_and_typeconversion.ipynb',
#  'day_7_literals.ipynb',
#  'day_8_operators.ipynb',
#  'day_9_if-else.ipynb',
#  'README.md']
