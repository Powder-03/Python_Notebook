# %%
name = 'Rishabh'
print(name)
# Out:
# Rishabh

# %%
#no variable declaration
#it supports dynamic typing

# %%
name = True
print(name)
# Out:
# True

# %%
#in python one variable is not binded by one datatype
#same variable can hold different datatypes at different times it is called dynamic binding

# %%
#special syntax
a=5; b=10; c=a+b
print(a, b, c)
# Out:
# 5 10 15

# %%
a,b = 5,10
